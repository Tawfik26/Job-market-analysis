# %% [markdown]
# 1. Import pandas as pd.

# %%
import pandas as pd

# %% [markdown]
# 2. Show first five records in your data.

# %%
df = pd.read_csv('example.csv')
df
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN  $107,790.00
# ...

# %% [markdown]
# 3. Get the overview of your data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  object
#  7   Hourly Rate        7883 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# 4. How many 'NaN' you have in each column in your data?

# %%
df.isnull().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        24775
# Annual Salary         7883
# Hourly Rate          24775
# dtype: int64

# %% [markdown]
# 5. Output the statistics for your dataset.

# %%
df.describe()
# Out:
#        Typical Hours
# count    7883.000000
# mean       34.698719
# std         9.145553
# min        10.000000
# 25%        20.000000
# 50%        40.000000
# 75%        40.000000
# max        40.000000

# %% [markdown]
# 6. What are the maximum, minimum and average Typical Hours? (use 'Typical Hours' column)

# %%
df[['Typical Hours']].max()
# Out:
# Typical Hours    40.0
# dtype: float64

# %%
df[['Typical Hours']].min()
# Out:
# Typical Hours    10.0
# dtype: float64

# %%
df[['Typical Hours']].mean()
# Out:
# Typical Hours    34.698719
# dtype: float64

# %% [markdown]
# 7. How many employees are on salary and how many are working on hourly basis?

# %%
df['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    24775
# Hourly     7883
# Name: count, dtype: int64

# %% [markdown]
# 8. Which department has maximum no of employees?

# %%
df['Department'].value_counts().head(1)
# Out:
# Department
# POLICE    12973
# Name: count, dtype: int64

# %% [markdown]
# 9. How many employees are on Salary and how many are on Hourly in the Police department?

# %%
df1 = df[df['Department'] == 'POLICE']
df1
# Out:
#                         Name      Job Titles Department Full or Part-Time  \
# 1            BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 4           DOLAN,  ROBERT J        SERGEANT     POLICE                 F
# 7            ELKINS,  ERIC J        SERGEANT     POLICE                 F
# 8           ESTRADA,  LUIS F  POLICE OFFICER     POLICE                 F
# 9            EWING,  MARIE A       CLERK III     POLICE                 F
# ...                      ...             ...        ...               ...
# 32652       ZYGMUNT,  DAWID   POLICE OFFICER     POLICE                 F
# 32653     ZYGOWICZ,  PETER J  POLICE OFFICER     POLICE                 F
# 32654  ZYLINSKA,  KATARZYNA   POLICE OFFICER     POLICE                 F
# 32655      ZYMANTAS,  MARK E  POLICE OFFICER     POLICE                 F
# 32656    ZYRKOWSKI,  CARLO E  POLICE OFFICER     POLICE                 F
#
#       Salary or Hourly  Typical Hours Annual Salary Hourly Rate
# ...

# %%
df1['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    12941
# Hourly       32
# Name: count, dtype: int64

# %% [markdown]
# 10. What are the mean, max and min salaries?

# %%
df2 = df['Annual Salary'].str.replace('$','').str.replace(',','').astype(float)
df2
# Out:
# 0        107790.0
# 1        104628.0
# 2        114324.0
# 3         76932.0
# 4        111474.0
#            ...
# 32653     90024.0
# 32654     48078.0
# 32655     87006.0
# 32656     93354.0
# 32657    115932.0
# Name: Annual Salary, Length: 32658, dtype: float64

# %%
df2.mean()
# Out:
# np.float64(87512.78024137235)

# %%
df2.min()
# Out:
# np.float64(0.96)

# %%
df2.max()
# Out:
# np.float64(300000.0)

# %% [markdown]
# 11. Find an employee who has the maximum salary.

# %%
df
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN  $107,790.00
# ...

# %%
df['Updated_Annual Salary'] = df2
df
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN  $107,790.00
# ...

# %%
df[df['Updated_Annual Salary'] == df['Updated_Annual Salary'].max()]
# Out:
#                   Name                Job Titles Department Full or Part-Time  \
# 8310  EVANS,  GINGER S  COMMISSIONER OF AVIATION   AVIATION                 F
#
#      Salary or Hourly  Typical Hours Annual Salary Hourly Rate  \
# 8310           Salary            NaN  $300,000.00          NaN
#
#       Updated_Annual Salary
# 8310               300000.0

# %% [markdown]
# 12. Find an employee who has the minimum salary.

# %%
df[df['Updated_Annual Salary'] == df['Updated_Annual Salary'].min()]
# Out:
#                  Name                Job Titles      Department  \
# 15387  KOCH,  STEVEN   ADMINISTRATIVE SECRETARY  MAYOR'S OFFICE
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 15387                 F           Salary            NaN        $0.96
#
#       Hourly Rate  Updated_Annual Salary
# 15387         NaN                   0.96

# %% [markdown]
# 13. What are the mean, max and min Hourly Rate?

# %%
df4 = df['Hourly Rate'].str.replace('$','').str.replace(',','').astype(float)
df4
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 32653   NaN
# 32654   NaN
# 32655   NaN
# 32656   NaN
# 32657   NaN
# Name: Hourly Rate, Length: 32658, dtype: float64

# %%
df['Updated_Hourly Rate'] = df4
df
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN  $107,790.00
# ...

# %%
df['Updated_Hourly Rate'].mean()
# Out:
# np.float64(32.86819231257135)

# %%
df['Updated_Hourly Rate'].max()
# Out:
# np.float64(96.0)

# %%
df['Updated_Hourly Rate'].min()
# Out:
# np.float64(2.65)

# %% [markdown]
# 14. How many employees are getting max Hourly Rate?

# %%
df['Updated_Hourly Rate'].max()
# Out:
# np.float64(96.0)

# %%
df[df['Updated_Hourly Rate'] == df['Updated_Hourly Rate'].max()]
# Out:
#                  Name    Job Titles Department Full or Part-Time  \
# 14317  JONES,  JOHN W  PSYCHIATRIST     HEALTH                 F
#
#       Salary or Hourly  Typical Hours Annual Salary Hourly Rate  \
# 14317           Hourly           35.0           NaN     $96.00
#
#        Updated_Annual Salary  Updated_Hourly Rate
# 14317                    NaN                 96.0

# %%
df[df['Updated_Hourly Rate'] == df['Updated_Hourly Rate'].max()].shape[0]
# Out:
# 1

# %% [markdown]
# 15. Who is getting max Hourly Rate?

# %%
df[df['Updated_Hourly Rate'] == df['Updated_Hourly Rate'].max()]
# Out:
#                  Name    Job Titles Department Full or Part-Time  \
# 14317  JONES,  JOHN W  PSYCHIATRIST     HEALTH                 F
#
#       Salary or Hourly  Typical Hours Annual Salary Hourly Rate  \
# 14317           Hourly           35.0           NaN     $96.00
#
#        Updated_Annual Salary  Updated_Hourly Rate
# 14317                    NaN                 96.0

# %%
df[df['Updated_Hourly Rate'] == df['Updated_Hourly Rate'].max()]['Name']
# Out:
# 14317    JONES,  JOHN W
# Name: Name, dtype: object

# %% [markdown]
# 16. How many employees are earning less than the average Hourly Rate?

# %%
df[df['Updated_Hourly Rate'] < df['Updated_Hourly Rate'].mean()].shape[0]
# Out:
# 2791

# %% [markdown]
# 17. How many employees are paid hourly and they have full-time job?

# %%
df
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN  $107,790.00
# ...

# %%
df[(df['Salary or Hourly'] == 'Hourly') & (df['Full or Part-Time'] == 'F')].shape[0]
# Out:
# 5906

# %% [markdown]
# 18. Find the full-time employees who are working at hourly rate of $10.00?

# %%
df[(df['Full or Part-Time'] == 'F') & (df['Salary or Hourly'] == 'Hourly') & (df['Updated_Hourly Rate'] == 10.00)]
# Out:
#                        Name          Job Titles       Department  \
# 1232      AYALA JR,  JESUS       STUDENT INTERN  HUMAN RESOURCES
# 4522   CERVANTES,  BIANCA A      STUDENT INTERN    BUDGET & MGMT
# 6476     DAVILA,  ROBERTO A     ALDERMANIC AIDE     CITY COUNCIL
# 16474         LEVY,  ETHAN   CLERK CITY COUNCIL     CITY COUNCIL
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 1232                  F           Hourly           35.0           NaN
# 4522                  F           Hourly           35.0           NaN
# 6476                  F           Hourly           35.0           NaN
# 16474                 F           Hourly           35.0           NaN
#
#       Hourly Rate  Updated_Annual Salary  Updated_Hourly Rate
# 1232      $10.00                     NaN                 10.0
# 4522      $10.00                     NaN                 10.0
# 6476      $10.00                     NaN                 10.0
# ...

# %% [markdown]
# 19. How many unique Job Titles are there in the data?

# %%
df['Job Titles'].nunique()
# Out:
# 1095

# %% [markdown]
# 20. What was the average Salary of the employees in each department?

# %%
df.groupby('Department')['Updated_Annual Salary'].mean()
# Out:
# Department
# ADMIN HEARNG             78912.947368
# ANIMAL CONTRL            66089.684211
# AVIATION                 76140.018777
# BOARD OF ELECTION        56051.142857
# BOARD OF ETHICS          94552.500000
# BUDGET & MGMT            93925.395349
# BUILDINGS                98864.833534
# BUSINESS AFFAIRS         80446.425000
# CITY CLERK               69762.439024
# CITY COUNCIL             63577.172069
# COMMUNITY DEVELOPMENT    88363.257143
# COPA                     98784.705882
# CULTURAL AFFAIRS         87048.909091
# DISABILITIES             82431.724138
# DoIT                     99681.029703
# FAMILY & SUPPORT         79013.588785
# FINANCE                  73276.364662
# FIRE                     97762.348662
# GENERAL SERVICES         83095.528390
# HEALTH                   85488.210938
# HUMAN RELATIONS          93778.588235
# HUMAN RESOURCES          79851.761194
# INSPECTOR GEN            84030.666667
# IPRA                     94429.285714
# ...

# %% [markdown]
# 21. What is the job title of 'AGAR,  BULENT B'? please note, there are two spaces between AGAR, and BULENT.

# %%
df[df['Name'] == 'AGAR,  BULENT B']['Job Titles']
# Out:
# 230    CHIEF ENGINEER OF SEWERS
# Name: Job Titles, dtype: object

# %%
df.loc[df['Name'] == 'AGAR,  BULENT B','Job Titles']
# Out:
# 230    CHIEF ENGINEER OF SEWERS
# Name: Job Titles, dtype: object

# %% [markdown]
# 22. What are the top most common job titles?

# %%
df['Job Titles'].value_counts().head()
# Out:
# Job Titles
# POLICE OFFICER                            9393
# FIREFIGHTER-EMT                           1424
# SERGEANT                                  1118
# POOL MOTOR TRUCK DRIVER                    996
# POLICE OFFICER (ASSIGNED AS DETECTIVE)     845
# Name: count, dtype: int64

# %% [markdown]
# 23. How many people have the word 'officer' in their job title? (This is pretty tricky)

# %%
df
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Annual Salary  \
# 0                     F           Salary            NaN  $107,790.00
# ...

# %%
df['Job Titles'].str.contains('officer', case=False, na=False).sum()
# Out:
# np.int64(11101)

# %% [markdown]
# 24. Save the final dataframe to a csv file

# %%
df.to_csv('Job market analysis_CSV.csv', index=False)
